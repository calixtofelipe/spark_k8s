# %%
from __future__ import print_function

import sys
if sys.version >= '3':
    long = int

from pyspark.sql import SparkSession

from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS
from pyspark.sql import Row

# %%
spark = SparkSession\
        .builder\
        .appName("ALS_ALGORITHM")\
        .getOrCreate()

# %%
lines = spark.read.text("movies_ratings.txt").rdd
parts = lines.map(lambda row: row.value.split("::"))
ratingsRDD = parts.map(lambda p: Row(userId=int(p[0]), movieId=int(p[1]),
                                     rating=float(p[2]), timestamp=long(p[3])))
ratings = spark.createDataFrame(ratingsRDD)

# %%
ratings.show(100)
# Out:
# +-------+------+----------+------+
# |movieId|rating| timestamp|userId|
# +-------+------+----------+------+
# |      2|   3.0|1424380312|     0|
# |      3|   1.0|1424380312|     0|
# |      5|   2.0|1424380312|     0|
# |      9|   4.0|1424380312|     0|
# |     11|   1.0|1424380312|     0|
# |     12|   2.0|1424380312|     0|
# |     15|   1.0|1424380312|     0|
# |     17|   1.0|1424380312|     0|
# |     19|   1.0|1424380312|     0|
# |     21|   1.0|1424380312|     0|
# |     23|   1.0|1424380312|     0|
# |     26|   3.0|1424380312|     0|
# |     27|   1.0|1424380312|     0|
# |     28|   1.0|1424380312|     0|
# |     29|   1.0|1424380312|     0|
# |     30|   1.0|1424380312|     0|
# |     31|   1.0|1424380312|     0|
# |     34|   1.0|1424380312|     0|
# |     37|   1.0|1424380312|     0|
# |     41|   2.0|1424380312|     0|
# |     44|   1.0|1424380312|     0|
# |     45|   2.0|1424380312|     0|
# |     46|   1.0|1424380312|     0|
# |     47|   1.0|1424380312|     0|
# |     48|   1.0|1424380312|     0|
# |     50|   1.0|1424380312|     0|
# |     51|   1.0|1424380312|     0|
# |     54|   1.0|1424380312|     0|
# |     55|   1.0|1424380312|     0|
# |     59|   2.0|1424380312|     0|
# |     61|   2.0|1424380312|     0|
# |     64|   1.0|1424380312|     0|
# |     67|   1.0|1424380312|     0|
# |     68|   1.0|1424380312|     0|
# |     69|   1.0|1424380312|     0|
# |     71|   1.0|1424380312|     0|
# |     72|   1.0|1424380312|     0|
# |     77|   2.0|1424380312|     0|
# |     79|   1.0|1424380312|     0|
# |     83|   1.0|1424380312|     0|
# |     87|   1.0|1424380312|     0|
# |     89|   2.0|1424380312|     0|
# |     91|   3.0|1424380312|     0|
# |     92|   4.0|1424380312|     0|
# |     94|   1.0|1424380312|     0|
# |     95|   2.0|1424380312|     0|
# |     96|   1.0|1424380312|     0|
# |     98|   1.0|1424380312|     0|
# |     99|   1.0|1424380312|     0|
# |      2|   2.0|1424380312|     1|
# |      3|   1.0|1424380312|     1|
# |      4|   2.0|1424380312|     1|
# |      6|   1.0|1424380312|     1|
# |      9|   3.0|1424380312|     1|
# |     12|   1.0|1424380312|     1|
# |     13|   1.0|1424380312|     1|
# |     14|   1.0|1424380312|     1|
# |     16|   1.0|1424380312|     1|
# |     19|   1.0|1424380312|     1|
# |     21|   3.0|1424380312|     1|
# |     27|   1.0|1424380312|     1|
# |     28|   3.0|1424380312|     1|
# |     33|   1.0|1424380312|     1|
# |     36|   2.0|1424380312|     1|
# |     37|   1.0|1424380312|     1|
# |     40|   1.0|1424380312|     1|
# |     41|   2.0|1424380312|     1|
# |     43|   1.0|1424380312|     1|
# |     44|   1.0|1424380312|     1|
# |     47|   1.0|1424380312|     1|
# |     50|   1.0|1424380312|     1|
# |     54|   1.0|1424380312|     1|
# |     56|   2.0|1424380312|     1|
# |     57|   1.0|1424380312|     1|
# |     58|   1.0|1424380312|     1|
# |     60|   1.0|1424380312|     1|
# |     62|   4.0|1424380312|     1|
# |     63|   1.0|1424380312|     1|
# |     67|   1.0|1424380312|     1|
# |     68|   4.0|1424380312|     1|
# |     70|   2.0|1424380312|     1|
# |     72|   1.0|1424380312|     1|
# |     73|   1.0|1424380312|     1|
# |     74|   2.0|1424380312|     1|
# |     76|   1.0|1424380312|     1|
# |     77|   3.0|1424380312|     1|
# |     78|   1.0|1424380312|     1|
# |     81|   1.0|1424380312|     1|
# |     82|   1.0|1424380312|     1|
# |     85|   3.0|1424380312|     1|
# |     86|   2.0|1424380312|     1|
# |     88|   2.0|1424380312|     1|
# |     91|   1.0|1424380312|     1|
# |     92|   2.0|1424380312|     1|
# |     93|   1.0|1424380312|     1|
# |     94|   2.0|1424380312|     1|
# |     96|   1.0|1424380312|     1|
# |     97|   1.0|1424380312|     1|
# |      4|   3.0|1424380312|     2|
# |      6|   1.0|1424380312|     2|
# +-------+------+----------+------+
# only showing top 100 rows

# %%
(training, test) = ratings.randomSplit([0.8, 0.2])

# %%
als = ALS(maxIter=5, regParam=0.01, userCol="userId", itemCol="movieId", ratingCol="rating",
              coldStartStrategy="drop")
model = als.fit(training)

# %%
predictions = model.transform(test)
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                    predictionCol="prediction")
rmse = evaluator.evaluate(predictions)
print("Root-mean-square error = " + str(rmse))
# Out:
# Root-mean-square error = 1.9788105980048145

# %%
userRecs = model.recommendForAllUsers(10)

# %%
userRecs.show(10, False)
# Out:
# +------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |userId|recommendations                                                                                                                                               |
# +------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |28    |[[46,5.355798], [32,5.1973286], [91,5.1836843], [69,5.03712], [12,4.9391327], [89,4.26267], [87,4.141993], [22,3.9555876], [66,3.9539108], [35,3.9065576]]    |
# |26    |[[94,5.4574556], [88,5.183529], [24,4.764553], [7,4.7160697], [38,4.396932], [36,4.16525], [68,4.025549], [73,3.9031422], [4,3.8591478], [9,3.8457222]]       |
# |27    |[[46,3.556524], [18,3.5069609], [54,3.2736502], [7,3.2522733], [88,3.2310824], [33,3.1425195], [80,2.9946015], [75,2.9854343], [83,2.979297], [19,2.9373174]] |
# |12    |[[65,5.479553], [64,4.977009], [17,4.737317], [35,4.369317], [32,4.1561184], [50,4.063442], [16,4.050937], [31,3.7305567], [94,3.6169326], [49,3.4489455]]    |
# |22    |[[54,5.100646], [74,5.028171], [75,5.018887], [24,4.945276], [51,4.926829], [88,4.7828407], [22,4.7456975], [94,4.5471625], [98,4.286485], [39,4.1184406]]    |
# |1     |[[17,4.553739], [90,3.9823298], [62,3.8898606], [20,3.5253477], [68,3.5129356], [9,3.2229056], [85,3.1137006], [77,3.0765243], [53,2.9427197], [94,2.6406212]]|
# |13    |[[53,3.7978308], [93,3.589258], [2,3.3576818], [29,3.2950826], [1,2.9606094], [39,2.8467145], [18,2.8348837], [74,2.7554624], [92,2.7073488], [25,2.5660992]] |
# |6     |[[25,5.0338297], [29,4.1014767], [8,3.980909], [93,3.697921], [39,3.583228], [43,3.404143], [40,3.3619769], [37,3.2521663], [83,3.08968], [85,2.8839586]]     |
# |16    |[[17,5.397605], [69,5.3215127], [85,4.914732], [51,4.797835], [76,4.4315085], [52,4.409823], [54,4.3893943], [53,4.3251553], [22,4.0715394], [29,4.044239]]   |
# |3     |[[18,4.251042], [32,4.1291127], [51,4.0121655], [75,3.9289703], [88,3.83724], [98,3.7996316], [54,3.7051685], [69,3.5434384], [29,3.5158784], [24,3.188407]]  |
# +------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
movieRecs = model.recommendForAllItems(10)

# %%
movieRecs.show(10, False)
# Out:
# +-------+-------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |movieId|recommendations                                                                                                                                              |
# +-------+-------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |31     |[[12,3.7305567], [23,3.5932126], [16,3.1825297], [14,3.0158415], [8,2.8461747], [9,2.3499084], [6,2.2296731], [7,2.0625465], [25,1.8526692], [21,1.7987369]] |
# |85     |[[16,4.914732], [8,4.8663273], [14,4.4541655], [17,3.689227], [7,3.5876262], [1,3.1137006], [6,2.8839586], [21,2.81791], [10,2.6213877], [22,2.617127]]      |
# |65     |[[12,5.479553], [23,5.1004734], [20,3.0673318], [9,2.9843714], [11,2.6549845], [15,1.9406167], [3,1.890595], [5,1.8414164], [19,1.8066692], [6,1.6617292]]   |
# |53     |[[24,7.8166633], [18,5.138023], [21,4.894886], [8,4.6802473], [0,4.5584087], [11,4.4027586], [16,4.3251553], [15,3.9364486], [13,3.7978308], [4,3.1504889]]  |
# |78     |[[18,1.6156389], [26,1.5058433], [25,1.1386789], [29,1.1318521], [9,1.114335], [22,1.103313], [24,1.0743948], [6,1.0705422], [21,1.0659853], [17,1.0437813]] |
# |34     |[[3,2.8681424], [24,2.504115], [20,2.4533925], [22,2.0883982], [11,1.995881], [2,1.4803755], [19,1.2403835], [16,1.1696904], [28,1.0775312], [21,1.0705256]] |
# |81     |[[18,2.8161654], [26,2.5346012], [9,2.2302117], [24,1.7446051], [5,1.731043], [29,1.7242086], [23,1.6690259], [4,1.6225141], [25,1.6127431], [0,1.5818076]]  |
# |28     |[[18,5.0215693], [9,3.2065277], [8,2.855547], [1,2.5571733], [12,2.2019758], [15,1.6601261], [26,1.5951955], [0,1.3787388], [23,1.3560319], [27,1.2424493]]  |
# |76     |[[14,4.702339], [16,4.4315085], [8,3.9721627], [21,3.5829825], [7,3.4886885], [3,2.9737625], [6,2.8400302], [22,2.5477483], [24,2.3852212], [4,1.954712]]    |
# |26     |[[24,3.7669318], [11,3.574648], [28,3.4317205], [21,2.4520745], [0,2.4394155], [5,2.4130757], [15,2.3589993], [25,2.0192766], [12,1.9945563], [13,1.6816003]]|
# +-------+-------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
users = ratings.select(als.getUserCol()).distinct()

# %%
users.show()
# Out:
# +------+
# |userId|
# +------+
# |    26|
# |    29|
# |    19|
# |     0|
# |    22|
# |     7|
# |    25|
# |     6|
# |     9|
# |    27|
# |    17|
# |    28|
# |     5|
# |     1|
# |    10|
# |     3|
# |    12|
# |     8|
# |    11|
# |     2|
# +------+
# only showing top 20 rows

# %%
userRecsOnlyItemId = userRecs.select(userRecs['userId'], userRecs['recommendations']['movieId'])

# %%
userRecsOnlyItemId.show(10, False)
# Out:
# +------+----------------------------------------+
# |userId|recommendations.movieId                 |
# +------+----------------------------------------+
# |28    |[46, 32, 91, 69, 12, 89, 87, 22, 66, 35]|
# |26    |[94, 88, 24, 7, 38, 36, 68, 73, 4, 9]   |
# |27    |[46, 18, 54, 7, 88, 33, 80, 75, 83, 19] |
# |12    |[65, 64, 17, 35, 32, 50, 16, 31, 94, 49]|
# |22    |[54, 74, 75, 24, 51, 88, 22, 94, 98, 39]|
# |1     |[17, 90, 62, 20, 68, 9, 85, 77, 53, 94] |
# |13    |[53, 93, 2, 29, 1, 39, 18, 74, 92, 25]  |
# |6     |[25, 29, 8, 93, 39, 43, 40, 37, 83, 85] |
# |16    |[17, 69, 85, 51, 76, 52, 54, 53, 22, 29]|
# |3     |[18, 32, 51, 75, 88, 98, 54, 69, 29, 24]|
# +------+----------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ## 50 recomendacoes para todos os usuarios

# %%
userRecs = model.recommendForAllUsers(50)

# %%
userRecs.show()
# Out:
# +------+--------------------+
# |userId|     recommendations|
# +------+--------------------+
# |    28|[[46,5.355798], [...|
# |    26|[[94,5.4574556], ...|
# |    27|[[46,3.556524], [...|
# |    12|[[65,5.479553], [...|
# |    22|[[54,5.100646], [...|
# |     1|[[17,4.553739], [...|
# |    13|[[53,3.7978308], ...|
# |     6|[[25,5.0338297], ...|
# |    16|[[17,5.397605], [...|
# |     3|[[18,4.251042], [...|
# |    20|[[18,5.245725], [...|
# |     5|[[66,4.2299576], ...|
# |    19|[[32,4.0966134], ...|
# |    15|[[53,3.9364486], ...|
# |    17|[[46,5.0480375], ...|
# |     9|[[49,4.9857273], ...|
# |     4|[[18,5.511528], [...|
# |     8|[[29,5.2466345], ...|
# |    23|[[65,5.1004734], ...|
# |     7|[[29,4.4058585], ...|
# +------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Recomenda 50 usuarios para os itens

# %%
movieRecs = model.recommendForAllItems(50)

# %%
movieRecs.show()
# Out:
# +-------+--------------------+
# |movieId|     recommendations|
# +-------+--------------------+
# |     31|[[12,3.7305567], ...|
# |     85|[[16,4.914732], [...|
# |     65|[[12,5.479553], [...|
# |     53|[[24,7.8166633], ...|
# |     78|[[18,1.6156389], ...|
# |     34|[[3,2.8681424], [...|
# |     81|[[18,2.8161654], ...|
# |     28|[[18,5.0215693], ...|
# |     76|[[14,4.702339], [...|
# |     26|[[24,3.7669318], ...|
# |     27|[[23,4.8367357], ...|
# |     44|[[18,2.9582152], ...|
# |     12|[[28,4.9391327], ...|
# |     91|[[28,5.1836843], ...|
# |     22|[[22,4.7456975], ...|
# |     93|[[2,4.9816723], [...|
# |     47|[[25,3.8437107], ...|
# |      1|[[18,6.134018], [...|
# |     52|[[24,5.0278773], ...|
# |     13|[[11,3.9801643], ...|
# +-------+--------------------+
# only showing top 20 rows

# %%
recomendationToSave = model.recommendForAllUsers(10)
recomendationToSave = recomendationToSave.select(recomendationToSave['userId'], recomendationToSave['recommendations']['movieId'].alias('movieId'))

# %%
import pymongo
from pymongo import MongoClient

client = MongoClient('localhost', 27017)
db = client.eadpuc

# %%
colecao = recomendationToSave.collect()

for row in colecao:
    print(row.asDict())
    db.suggestions.insert_one(row.asDict())
# Out:
# {'userId': 28, 'movieId': [46, 32, 91, 69, 12, 89, 87, 22, 66, 35]}
# {'userId': 26, 'movieId': [94, 88, 24, 7, 38, 36, 68, 73, 4, 9]}
# {'userId': 27, 'movieId': [46, 18, 54, 7, 88, 33, 80, 75, 83, 19]}
# {'userId': 12, 'movieId': [65, 64, 17, 35, 32, 50, 16, 31, 94, 49]}
# {'userId': 22, 'movieId': [54, 74, 75, 24, 51, 88, 22, 94, 98, 39]}
# {'userId': 1, 'movieId': [17, 90, 62, 20, 68, 9, 85, 77, 53, 94]}
# {'userId': 13, 'movieId': [53, 93, 2, 29, 1, 39, 18, 74, 92, 25]}
# {'userId': 6, 'movieId': [25, 29, 8, 93, 39, 43, 40, 37, 83, 85]}
# {'userId': 16, 'movieId': [17, 69, 85, 51, 76, 52, 54, 53, 22, 29]}
# {'userId': 3, 'movieId': [18, 32, 51, 75, 88, 98, 54, 69, 29, 24]}
# {'userId': 20, 'movieId': [18, 90, 22, 38, 94, 68, 77, 60, 75, 17]}
# {'userId': 5, 'movieId': [66, 68, 49, 90, 69, 94, 62, 13, 48, 50]}
# {'userId': 19, 'movieId': [32, 98, 7, 24, 94, 36, 88, 8, 74, 54]}
# {'userId': 15, 'movieId': [53, 1, 18, 90, 2, 10, 59, 35, 17, 38]}
# {'userId': 17, 'movieId': [46, 20, 90, 17, 55, 62, 68, 22, 10, 85]}
# {'userId': 9, 'movieId': [49, 7, 27, 32, 23, 1, 87, 18, 33, 16]}
# {'userId': 4, 'movieId': [18, 38, 90, 41, 52, 70, 4, 27, 19, 29]}
# {'userId': 8, 'movieId': [29, 85, 53, 93, 25, 76, 2, 58, 62, 52]}
# {'userId': 23, 'movieId': [65, 32, 49, 27, 35, 50, 23, 18, 30, 13]}
# {'userId': 7, 'movieId': [29, 25, 8, 85, 93, 76, 72, 62, 52, 47]}
# {'userId': 10, 'movieId': [40, 19, 25, 42, 49, 46, 4, 83, 89, 85]}
# {'userId': 25, 'movieId': [63, 46, 49, 69, 27, 33, 47, 10, 71, 12]}
# {'userId': 24, 'movieId': [53, 18, 38, 52, 90, 69, 29, 30, 2, 72]}
# {'userId': 29, 'movieId': [46, 90, 32, 18, 49, 94, 27, 22, 87, 75]}
# {'userId': 21, 'movieId': [29, 93, 53, 69, 72, 52, 2, 74, 76, 1]}
# {'userId': 11, 'movieId': [32, 30, 48, 23, 69, 18, 27, 53, 90, 52]}
# {'userId': 14, 'movieId': [29, 63, 52, 76, 85, 72, 62, 47, 96, 58]}
# {'userId': 2, 'movieId': [25, 39, 8, 93, 83, 37, 40, 43, 92, 2]}
# {'userId': 0, 'movieId': [53, 18, 38, 90, 1, 92, 9, 2, 74, 66]}
# {'userId': 18, 'movieId': [1, 7, 74, 92, 53, 83, 28, 9, 18, 38]}

# %%
recomendationToSave.show()
# Out:
# +------+--------------------+
# |userId|             movieId|
# +------+--------------------+
# |    28|[46, 32, 91, 69, ...|
# |    26|[94, 88, 24, 7, 3...|
# |    27|[46, 18, 54, 7, 8...|
# |    12|[65, 64, 17, 35, ...|
# |    22|[54, 74, 75, 24, ...|
# |     1|[17, 90, 62, 20, ...|
# |    13|[53, 93, 2, 29, 1...|
# |     6|[25, 29, 8, 93, 3...|
# |    16|[17, 69, 85, 51, ...|
# |     3|[18, 32, 51, 75, ...|
# |    20|[18, 90, 22, 38, ...|
# |     5|[66, 68, 49, 90, ...|
# |    19|[32, 98, 7, 24, 9...|
# |    15|[53, 1, 18, 90, 2...|
# |    17|[46, 20, 90, 17, ...|
# |     9|[49, 7, 27, 32, 2...|
# |     4|[18, 38, 90, 41, ...|
# |     8|[29, 85, 53, 93, ...|
# |    23|[65, 32, 49, 27, ...|
# |     7|[29, 25, 8, 85, 9...|
# +------+--------------------+
# only showing top 20 rows
